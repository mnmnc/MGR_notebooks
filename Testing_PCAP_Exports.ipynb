# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
dframe = pd.read_csv('D:\\Data\\n.csv')

# %%
dframe_selected = DataFrame(dframe, columns=['frame.number', 'ip.ttl'])

# %% [markdown]
# dframe_selected

# %%
dframe_selected.fillna(0, inplace=True)

# %%
dframe_selected.drop('frame.number', axis=1, inplace=True)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
plt.hist(dframe_selected['ip.ttl'], bins=100)
# Out:
# (array([  4.09920000e+04,   8.61000000e+02,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           2.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   5.00000000e+00,
#           7.93000000e+02,   4.29000000e+02,   6.20000000e+01,
#           2.70000000e+01,   0.00000000e+00,   1.40000000e+01,
#           0.00000000e+00,   1.06500000e+03,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
# ...

# %%
sns.jointplot(dframe['ip.ttl'], dframe['frame.number'])

# %%
dframe.head()
# Out:
#    frame.number  frame.time_epoch  frame.len       ip.src           ip.dst  \
# 0             1      1.358009e+09         60          NaN              NaN
# 1             2      1.358009e+09        342  192.168.0.1  239.255.255.250
# 2             3      1.358009e+09        398  192.168.0.1  239.255.255.250
# 3             4      1.358009e+09        326  192.168.0.1  239.255.255.250
# 4             5      1.358009e+09        318  192.168.0.1  239.255.255.250
#
#    ip.ttl  tcp.srcport  tcp.dstport  tcp.flags  tcp.seq  tcp.stream  \
# 0     NaN          NaN          NaN        NaN      NaN         NaN
# 1       4          NaN          NaN        NaN      NaN         NaN
# 2       4          NaN          NaN        NaN      NaN         NaN
# 3       4          NaN          NaN        NaN      NaN         NaN
# 4       4          NaN          NaN        NaN      NaN         NaN
#
#    udp.srcport  udp.dstport  icmp.type  icmp.code
# 0          NaN          NaN        NaN        NaN
# ...

# %%
dframe = dframe.fillna(0)

plt.hist(dframe['frame.len'], bins=1000)
# Out:
# (array([  2.40000000e+01,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.21900000e+04,   1.70000000e+01,   1.11900000e+03,
#           6.00000000e+00,   1.04600000e+03,   8.00000000e+00,
#           6.00000000e+00,   2.89000000e+02,   1.00000000e+00,
#           8.70000000e+01,   8.00000000e+00,   8.00000000e+00,
#           9.00000000e+00,   4.00000000e+00,   5.40000000e+01,
#           2.88000000e+02,   9.30000000e+02,   5.37000000e+02,
#           1.40000000e+01,   2.30000000e+01,   9.43000000e+02,
#           2.08100000e+03,   2.00000000e+00,   2.00000000e+00,
#           6.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   5.00000000e+01,   0.00000000e+00,
#           2.00000000e+00,   4.00000000e+00,   1.00000000e+01,
# ...

# %%
# CHANGE FIGURE SIZE

import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 12

# %%
plt.hist(dframe['frame.len'], bins=1000)
# Out:
# (array([  2.40000000e+01,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.21900000e+04,   1.70000000e+01,   1.11900000e+03,
#           6.00000000e+00,   1.04600000e+03,   8.00000000e+00,
#           6.00000000e+00,   2.89000000e+02,   1.00000000e+00,
#           8.70000000e+01,   8.00000000e+00,   8.00000000e+00,
#           9.00000000e+00,   4.00000000e+00,   5.40000000e+01,
#           2.88000000e+02,   9.30000000e+02,   5.37000000e+02,
#           1.40000000e+01,   2.30000000e+01,   9.43000000e+02,
#           2.08100000e+03,   2.00000000e+00,   2.00000000e+00,
#           6.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   5.00000000e+01,   0.00000000e+00,
#           2.00000000e+00,   4.00000000e+00,   1.00000000e+01,
# ...

# %%
plt.scatter(dframe['frame.len'], dframe['ip.ttl'])

# %%
dframe.head()
# Out:
#    frame.number  frame.time_epoch  frame.len       ip.src           ip.dst  \
# 0             1      1.358009e+09         60            0                0
# 1             2      1.358009e+09        342  192.168.0.1  239.255.255.250
# 2             3      1.358009e+09        398  192.168.0.1  239.255.255.250
# 3             4      1.358009e+09        326  192.168.0.1  239.255.255.250
# 4             5      1.358009e+09        318  192.168.0.1  239.255.255.250
#
#    ip.ttl  tcp.srcport  tcp.dstport  tcp.flags  tcp.seq  tcp.stream  \
# 0       0            0            0          0        0           0
# 1       4            0            0          0        0           0
# 2       4            0            0          0        0           0
# 3       4            0            0          0        0           0
# 4       4            0            0          0        0           0
#
#    udp.srcport  udp.dstport  icmp.type  icmp.code
# 0            0            0          0          0
# ...

# %%
plt.scatter(dframe['frame.number'], dframe['tcp.flags'])
